# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
sns.set()

# %matplotlib inline

# %% [markdown]
# # Factors that affect Fb Campaigns
#
# <b> Targeting </b>
# <ul>
#     <li> Age </li>
#     <li> Gender </li>
#     <li> Location </li>
#     <li> Interest and Behaviour </li>
# </ul>
#
# <b> Ad Operations </b>
# <ul>
#     <li> Time Slot </li>
#     <li> Day of Week </li>
#     <li> Device </li>
#     <li> Platform </li>
#     <li> Frequency </li>
# </ul>
#
# <b> Ad Appearance </b>
# <ul>
#     <li> Ad Format </li>
#     <li> Ad Copy  </li>
#     <li> Device </li>
#     <li> Platform </li>
#     <li> Frequency </li>
# </ul>
#
# <b> Budget </b>

# %% [markdown]
# # Facebook Targeting Permutuations and Combinations

# %% [markdown]
# ![Facebook%20Data%20Export.png](attachment:Facebook%20Data%20Export.png)

# %%
# To convert into full screen Python 

from IPython.core.display import display, HTML
display(HTML("<style>.container {width:100% !important; }</style>"))
# Out:
# <style>.container {width:100% !important; }</style>

# %%
data = pd.read_csv('UCMAS - 1. Report Targeting.csv')

# %%
data
# Out:
#                                Campaign Name  \
# 0     UCMAS 2nd Ad Demo Class 19th September
# 1  UCMAS Online Classes Ghana 24th Sept 2020
# 2            UCMAS Demo Class 19th September
# 3   UCMAS Online Classes Ghana 01st Oct 2020
#
#                                          Ad Set Name               Ad Name  \
# 0  UCMAS Demo Class, Ghana , W 24-35, Parents + I...              Image Ad
# 1                             W + Parents + Intersts                 Video
# 2  UCMAS Demo Class, Ghana , W 24-35, Parents + I...  Testimonial Video Ad
# 3                             W + Parents + Intersts                 Image
#
#                              Campaign Name.1        Result Type  Results  \
# 0     UCMAS 2nd Ad Demo Class 19th September  On-Facebook Leads       43
# 1  UCMAS Online Classes Ghana 24th Sept 2020  On-Facebook Leads       63
# 2            UCMAS Demo Class 19th September  On-Facebook Leads       42
# 3   UCMAS Online Classes Ghana 01st Oct 2020  On-Facebook Leads       46
#
#    Reach  Impressions  Cost per Result  Amount Spent (INR)  Result Rate  \
# 0  16296        40426       139.626512             6003.94     0.106367
# 1  24999        56478        93.780476             5908.17     0.111548
# 2  18472        39364       130.146905             5466.17     0.106696
# 3  25369        56778       111.437174             5126.11     0.081017
#
#    Frequency  Clicks (All)  CTR (All)  CPM (Cost per 1,000 Impressions)  \
# 0   2.480731           756   1.870084                        148.516796
# 1   2.259210          1090   1.929955                        104.610114
# 2   2.131009           796   2.022152                        138.862158
# 3   2.238086          1108   1.951460                         90.283384
#
#   Reporting Starts Reporting Ends
# 0       2020-09-06     2020-10-05
# 1       2020-09-06     2020-10-05
# 2       2020-09-06     2020-10-05
# 3       2020-09-06     2020-10-05

# %% [markdown]
# # Data Cleaning

# %%
data.drop(['Reporting Starts', 'Reporting Ends'], axis = 1, inplace = True)

# %%
data
# Out:
#                                Campaign Name  \
# 0     UCMAS 2nd Ad Demo Class 19th September
# 1  UCMAS Online Classes Ghana 24th Sept 2020
# 2            UCMAS Demo Class 19th September
# 3   UCMAS Online Classes Ghana 01st Oct 2020
#
#                                          Ad Set Name               Ad Name  \
# 0  UCMAS Demo Class, Ghana , W 24-35, Parents + I...              Image Ad
# 1                             W + Parents + Intersts                 Video
# 2  UCMAS Demo Class, Ghana , W 24-35, Parents + I...  Testimonial Video Ad
# 3                             W + Parents + Intersts                 Image
#
#                              Campaign Name.1        Result Type  Results  \
# 0     UCMAS 2nd Ad Demo Class 19th September  On-Facebook Leads       43
# 1  UCMAS Online Classes Ghana 24th Sept 2020  On-Facebook Leads       63
# 2            UCMAS Demo Class 19th September  On-Facebook Leads       42
# 3   UCMAS Online Classes Ghana 01st Oct 2020  On-Facebook Leads       46
#
#    Reach  Impressions  Cost per Result  Amount Spent (INR)  Result Rate  \
# 0  16296        40426       139.626512             6003.94     0.106367
# 1  24999        56478        93.780476             5908.17     0.111548
# 2  18472        39364       130.146905             5466.17     0.106696
# 3  25369        56778       111.437174             5126.11     0.081017
#
#    Frequency  Clicks (All)  CTR (All)  CPM (Cost per 1,000 Impressions)
# 0   2.480731           756   1.870084                        148.516796
# 1   2.259210          1090   1.929955                        104.610114
# 2   2.131009           796   2.022152                        138.862158
# 3   2.238086          1108   1.951460                         90.283384

# %%
data.shape
# Out:
# (4, 15)

# %%
data.isnull().sum()
# Out:
# Campaign Name                       0
# Ad Set Name                         0
# Ad Name                             0
# Campaign Name.1                     0
# Result Type                         0
# Results                             0
# Reach                               0
# Impressions                         0
# Cost per Result                     0
# Amount Spent (INR)                  0
# Result Rate                         0
# Frequency                           0
# Clicks (All)                        0
# CTR (All)                           0
# CPM (Cost per 1,000 Impressions)    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 15 columns):
# Campaign Name                       4 non-null object
# Ad Set Name                         4 non-null object
# Ad Name                             4 non-null object
# Campaign Name.1                     4 non-null object
# Result Type                         4 non-null object
# Results                             4 non-null int64
# Reach                               4 non-null int64
# Impressions                         4 non-null int64
# Cost per Result                     4 non-null float64
# Amount Spent (INR)                  4 non-null float64
# Result Rate                         4 non-null float64
# Frequency                           4 non-null float64
# Clicks (All)                        4 non-null int64
# CTR (All)                           4 non-null float64
# CPM (Cost per 1,000 Impressions)    4 non-null float64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 608.0+ bytes

# %%
data.drop(['Campaign Name.1'], axis = 1, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 14 columns):
# Campaign Name                       4 non-null object
# Ad Set Name                         4 non-null object
# Ad Name                             4 non-null object
# Result Type                         4 non-null object
# Results                             4 non-null int64
# Reach                               4 non-null int64
# Impressions                         4 non-null int64
# Cost per Result                     4 non-null float64
# Amount Spent (INR)                  4 non-null float64
# Result Rate                         4 non-null float64
# Frequency                           4 non-null float64
# Clicks (All)                        4 non-null int64
# CTR (All)                           4 non-null float64
# CPM (Cost per 1,000 Impressions)    4 non-null float64
# dtypes: float64(6), int64(4), object(4)
# memory usage: 576.0+ bytes

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## 1. Create Cost per Click Column

# %%
data['CPC'] = data['Amount Spent (INR)'] / data['Clicks (All)']

# %%
data
# Out:
#                                Campaign Name  \
# 0     UCMAS 2nd Ad Demo Class 19th September
# 1  UCMAS Online Classes Ghana 24th Sept 2020
# 2            UCMAS Demo Class 19th September
# 3   UCMAS Online Classes Ghana 01st Oct 2020
#
#                                          Ad Set Name               Ad Name  \
# 0  UCMAS Demo Class, Ghana , W 24-35, Parents + I...              Image Ad
# 1                             W + Parents + Intersts                 Video
# 2  UCMAS Demo Class, Ghana , W 24-35, Parents + I...  Testimonial Video Ad
# 3                             W + Parents + Intersts                 Image
#
#          Result Type  Results  Reach  Impressions  Cost per Result  \
# 0  On-Facebook Leads       43  16296        40426       139.626512
# 1  On-Facebook Leads       63  24999        56478        93.780476
# 2  On-Facebook Leads       42  18472        39364       130.146905
# 3  On-Facebook Leads       46  25369        56778       111.437174
#
#    Amount Spent (INR)  Result Rate  Frequency  Clicks (All)  CTR (All)  \
# 0             6003.94     0.106367   2.480731           756   1.870084
# 1             5908.17     0.111548   2.259210          1090   1.929955
# 2             5466.17     0.106696   2.131009           796   2.022152
# 3             5126.11     0.081017   2.238086          1108   1.951460
#
#    CPM (Cost per 1,000 Impressions)       CPC
# 0                        148.516796  7.941720
# 1                        104.610114  5.420339
# 2                        138.862158  6.867048
# 3                         90.283384  4.626453

# %% [markdown]
# ## 2. Put Frequency into buckets

# %%
data['Frequency'] = data['Frequency'].apply(lambda x: '1 to 2' if x<2
                                                    else '2 to 3' if x >=2 and x<3
                                                    else '3 to 4' if x >=3 and x<4
                                                    else '4 to 5' if x >=4 and x<5
                                                    else 'More than 5')

# %%
data
# Out:
#                                Campaign Name  \
# 0     UCMAS 2nd Ad Demo Class 19th September
# 1  UCMAS Online Classes Ghana 24th Sept 2020
# 2            UCMAS Demo Class 19th September
# 3   UCMAS Online Classes Ghana 01st Oct 2020
#
#                                          Ad Set Name               Ad Name  \
# 0  UCMAS Demo Class, Ghana , W 24-35, Parents + I...              Image Ad
# 1                             W + Parents + Intersts                 Video
# 2  UCMAS Demo Class, Ghana , W 24-35, Parents + I...  Testimonial Video Ad
# 3                             W + Parents + Intersts                 Image
#
#          Result Type  Results  Reach  Impressions  Cost per Result  \
# 0  On-Facebook Leads       43  16296        40426       139.626512
# 1  On-Facebook Leads       63  24999        56478        93.780476
# 2  On-Facebook Leads       42  18472        39364       130.146905
# 3  On-Facebook Leads       46  25369        56778       111.437174
#
#    Amount Spent (INR)  Result Rate Frequency  Clicks (All)  CTR (All)  \
# 0             6003.94     0.106367    2 to 3           756   1.870084
# 1             5908.17     0.111548    2 to 3          1090   1.929955
# 2             5466.17     0.106696    2 to 3           796   2.022152
# 3             5126.11     0.081017    2 to 3          1108   1.951460
#
#    CPM (Cost per 1,000 Impressions)       CPC
# 0                        148.516796  7.941720
# 1                        104.610114  5.420339
# 2                        138.862158  6.867048
# 3                         90.283384  4.626453

# %%
data.to_csv('1.1 Report_Targeting_Cleaned.csv')

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## 1. Effect of Targeting + Ad Set Name + Budget

# %% [markdown]
# ### Generic View

# %%
plt.figure(figsize=(22,10))

#subplot 1
plt.subplot(1,6,1)
sns.barplot(x = 'Ad Set Name', y = 'Amount Spent (INR)', data = data, estimator = np.sum, ci = None)
plt.title("Total Amount Spent")
plt.xticks(rotation = 90)

#subplot 2 
plt.subplot(1,6,2)
sns.barplot(x = 'Ad Set Name', y = 'Clicks (All)', data = data, estimator = np.sum, ci = None)
plt.title("Total Clicks")
plt.xticks(rotation = 90)


#subplot 3 
plt.subplot(1,6,3)
sns.barplot(x = 'Ad Set Name', y = 'CTR (All)', data = data, estimator = np.mean, ci = None)
plt.title("Total CTR")
plt.xticks(rotation = 90)


#subplot 4
plt.subplot(1,6,4)
sns.barplot(x = 'Ad Set Name', y = 'Results', data = data, estimator = np.sum, ci = None)
plt.title("Total Conversions")
plt.xticks(rotation = 90)

#subplot 5
plt.subplot(1,6,5)
sns.barplot(x = 'Ad Set Name', y = 'Cost per Result', data = data, estimator = np.mean, ci = None)
plt.title("Avg cost per conversion")
plt.xticks(rotation = 90)

#subplot 6 
plt.subplot(1,6,6)
sns.barplot(x = 'Ad Set Name', y = 'Result Rate', data = data, estimator = np.mean, ci = None)
plt.title("Conversion Rate")
plt.xticks(rotation = 90)

plt.tight_layout(pad = 0.7)
plt.show()

# %% [markdown]
# ### Granular View

# %%
sns.catplot(y = 'Ad Name', x = 'Amount Spent (INR)', col = 'Ad Set Name', data = data, kind = 'bar', aspect = 1.3, estimator = np.sum, ci = None)
plt.subplots_adjust(top = 0.85)
plt.suptitle('Total Amount Spent on Each Ad', fontsize = 20)

sns.catplot(y = 'Ad Name', x = 'Clicks (All)', col = 'Ad Set Name', data = data, kind = 'bar', aspect = 1.3, estimator = np.sum, ci = None)
plt.subplots_adjust(top = 0.85)
plt.suptitle('Total Clicks', fontsize = 20)

sns.catplot(y = 'Ad Name', x = 'CTR (All)', col = 'Ad Set Name', data = data, kind = 'bar', aspect = 1.3, estimator = np.mean, ci = None)
plt.subplots_adjust(top = 0.85)
plt.suptitle('Avg Click Through Rate', fontsize = 20)

sns.catplot(y = 'Ad Name', x = 'Results', col = 'Ad Set Name', data = data, kind = 'bar', aspect = 1.3, estimator = np.sum, ci = None)
plt.subplots_adjust(top = 0.85)
plt.suptitle('Total Conversions', fontsize = 20)

sns.catplot(y = 'Ad Name', x = 'Cost per Result', col = 'Ad Set Name', data = data, kind = 'bar', aspect = 1.3, estimator = np.mean, ci = None)
plt.subplots_adjust(top = 0.85)
plt.suptitle('Avg Cost per Conversion', fontsize = 20)

sns.catplot(y = 'Ad Name', x = 'Result Rate', col = 'Ad Set Name', data = data, kind = 'bar', aspect = 1.3, estimator = np.mean, ci = None)
plt.subplots_adjust(top = 0.85)
plt.suptitle('Avg Conversion Rate', fontsize = 20)
# Out:
# Text(0.5, 0.98, 'Avg Conversion Rate')

# %% [markdown]
# ## 2. Effect of Targeting + Frequency + Budget

# %%
data = data.sort_values(by = ['Frequency'])

# %% [markdown]
# ## Generic

# %%
plt.figure(figsize=(22,10))

#subplot 1
plt.subplot(1,6,1)
sns.barplot(x = 'Frequency', y = 'Amount Spent (INR)', data = data, estimator = np.sum, ci = None)
plt.title("Total Amount Spent")
plt.xticks(rotation = 90)

#subplot 2 
plt.subplot(1,6,2)
sns.barplot(x = 'Frequency', y = 'Clicks (All)', data = data, estimator = np.sum, ci = None)
plt.title("Total Clicks")
plt.xticks(rotation = 90)


#subplot 3 
plt.subplot(1,6,3)
sns.barplot(x = 'Frequency', y = 'CTR (All)', data = data, estimator = np.mean, ci = None)
plt.title("Total CTR")
plt.xticks(rotation = 90)


#subplot 4
plt.subplot(1,6,4)
sns.barplot(x = 'Frequency', y = 'Results', data = data, estimator = np.sum, ci = None)
plt.title("Total Conversions")
plt.xticks(rotation = 90)

#subplot 5
plt.subplot(1,6,5)
sns.barplot(x = 'Frequency', y = 'Cost per Result', data = data, estimator = np.mean, ci = None)
plt.title("Avg cost per conversion")
plt.xticks(rotation = 90)

#subplot 6 
plt.subplot(1,6,6)
sns.barplot(x = 'Frequency', y = 'Result Rate', data = data, estimator = np.mean, ci = None)
plt.title("Conversion Rate")
plt.xticks(rotation = 90)

plt.tight_layout(pad = 0.7)
plt.show()

# %% [markdown]
# There is only 1 frequency here so cannot analyze much
